# %%
# importing libraries
import Phonon_Number as pn
import parameters as params

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
from IPython.display import clear_output
from scipy.io import savemat, loadmat
from scipy.optimize import minimize
from scipy.special import gamma as gamma_function

# %%
def calculate_error(parameters):
    '''
    Returns absolute log error between phonon(t) and fit(t)    
    '''
    decay_rate, beta = parameters

    fit = pn.stretched_exponential(time, decay_rate, beta)
    error = np.sum(np.abs(np.log10(phonon) - np.log10(fit)))/len(phonon)
    
    return error

def save_data():
    polariton_phonon_decay_thermal_N_40 = {'T2' : T2,
                                           'pump' : pump,
                                           'nth' : nth,
                                           'g' : g,
                                           'temperature' : temperature,
                                           'gamma' : gamma,
                                           'omega_m' : omega_m,
                                           'N' : N,
                                           'decay_rate' : decay_rate,
                                           'best_fit_error': best_fit_error,
                                           'beta_array': beta_array,
                                           'phonon_ss': phonon_ss,
                                           'phonon_number_array': phonon_number_array,
                                           'best_fit_array': best_fit_array,
                                           'average_error':average_error,
                                           't_final_array': t_final_array
                                          }
            
    savemat("./data files/polariton_phonon_decay_thermal_N_40.mat", polariton_phonon_decay_thermal_N_40)

# %%
'''
Define and initialize parameters
'''

# Import parameters
G, omega_m, g, gamma, temperature, nth = params.polariton_params()

N = 40                                    # truncation of phonon number basis in qutip

gamma = omega_m*10**-7                      # in MHz
dephasing = 0                               # in MHz
incoherent_pump = 0                         # in MHz

print('nth =', nth)

initial_state = pn.calculate_initial_state(N, nth)
print('initial phonons = ', pn.calculate_phonon_number(initial_state, N))

data_points = 30
T2 = np.logspace(-1,1,data_points)*g
pump = np.logspace(-1,1,data_points)*g

# Defining arrays to store data
decay_rate = np.zeros((len(pump), len(T2)))
beta_array = np.zeros((len(pump), len(T2)))
t_final_array = np.zeros((len(pump), len(T2)))
phonon_number_array = np.zeros((len(pump), len(T2), 5000))
phonon_ss = np.zeros((len(pump), len(T2)))

best_fit_error = np.zeros((len(pump), len(T2)))
best_fit_array = []
average_error = np.zeros((len(pump), len(T2)))
# Out:
# nth = 5.00000686423051
# initial phonons =  4.9727729721705805

# %%
'''
Import data from datasets
'''

polariton_phonon_decay_thermal = loadmat('./data files/polariton_phonon_decay_thermal_N_40.mat')
phonon_number_array = polariton_phonon_decay_thermal['phonon_number_array']
t_final_array = polariton_phonon_decay_thermal['t_final_array']
phonon_ss = polariton_phonon_decay_thermal['phonon_ss']

# %% [markdown]
# ### Calculate and store phonon number as a function of time

# %%
'''
Iterate over T2 and pump arrays to calculate phonon_number(t) and t_final and store in respective arrays
'''

for i in range(len(pump)):
    for j in range(len(T2)):
        
        T1 = T2[j]
            
        if(i%10 == 0 or j%10 == 0):                 # saving data in between
            save_data()
            
        if(t_final_array[i,j] == 0):                # run if the index has not been initialized
        
            t_final = max(5000/(T2[j]), 1000)       # time for simulation for QD case (in ns)
        
            loop_again = True                       # check for looping again
            counter = 0                             # count the number of loops for one set of values of pump and T2
            print('index at: (', i,j, ')') 
            
            while(loop_again):    # loop until steadystate is verified by the function check_ss()
                counter = counter + 1
                
                # Define Hamiltonian and collapse operators
                Hamiltonian, collapse_ops = pn.polariton_system(g, pump[i], T2[j], gamma, dephasing, incoherent_pump, nth, N)
                
                # Create time array
                time = np.linspace(0, t_final, 5000)
                
                # Simulate the system to calculate phonon(t)
                phonon = pn.master_eq_solver(Hamiltonian, initial_state, time, collapse_ops, N)
                
                # Calculate the steady state phonon number
                phonon_ss[i,j] = pn.steady_state_phonon(Hamiltonian, collapse_ops, N)
                
                # check for steadystate
                check = pn.check_ss(phonon, phonon_ss[i,j])

                # check for steadystate
                check = pn.check_ss(phonon, phonon_ss[i,j])
                
                if(check):                      # if true, store data
                    phonon_number_array[i,j,:] = phonon
                    t_final_array[i,j] = t_final
                    
                    loop_again = False           # break the while loop
                else:                            # else, increase time for simulation and run again
                    t_final = t_final*3          # if check failed, increase time for simulation and run again
                
        
            # plot fits and formatting
            plt.figure()
            plt.title('counter = {}, index: (', i,j,')'.format(counter), fontsize = 12)
            plt.semilogy(time, phonon, label = 'phonon #', linewidth = 4)
            fig = plt.gcf()
            fig.set_size_inches((10, 5), forward=False)
            plt.xticks(fontsize = 12)
            plt.yticks(fontsize = 12)
            plt.savefig('./polariton_phonon_decay_thermal/Plot({}, {})'.format(i,j))
            plt.close()

save_data()

# %% [markdown]
# ### Fitting extended exponential function to phonon number

# %%
'''
Calculating the best fist and subsequently the corresponding decay rate and beta values.

- Using scipy.optimize.minmize for fitting
- Initial condition for an index tuple is the decay rate of the previous index; decay_rate_init[i,j] = decay_rate[i,j-1].
-- When j = 0; decay_rate_init[i,j] = decay_rate[i-1,0]
-- When i = 0 = j; decay_rate_init[0,0] = 10**-2
-- Tolerance is set to 10**-10

'''

for i in range(len(pump)):
    
    if(i == 0):
        decay_rate_init = 10**-2
    else:
        decay_rate_init = decay_rate[i-1, 0]
    
    for j in range(len(T2)):
        
        print('(',i,j,'); oldie error = ', average_error[i,j])
        
        # Initialize arrays
        phonon = phonon_number_array[i,j]
        time = np.linspace(0, t_final_array[i,j], 5000)
        
        # Calculating the value of the variable index
        index = pn.find_index(phonon, phonon_ss[i,j])
        
        # Shrink the arrays for fitting
        time = time[:index]
        phonon = phonon[:index]
        
        # Calculate best fit using scipy.minimize
        result_best_fit = minimize(calculate_error, x0 = [decay_rate_init, 1], bounds = [(10**-4, 10**2), (0, 1)], tol = 10**-10)
        
        # Substitute values
        decay_rate[i,j] = result_best_fit.x[0]
        beta_array[i,j] = result_best_fit.x[1]
        best_fit_error[i,j] = result_best_fit.fun
        
        # Create best fit array using best fit parameters and store
        best_fit = pn.stretched_exponential(time, decay_rate[i,j], beta_array[i,j], phonon_ss[i,j], nth)
        best_fit_array.append(best_fit)
        
        # Calculate average error
        average_error[i,j] = pn.calculate_average_error(best_fit, phonon)

        print('average error = ', average_error[i,j])
        
        counter = 'post_processing'
        
        # Re-initialize the initial condition for decay_rate for scipy.minimize
        decay_rate_init = decay_rate[i,j]
        
        plt.figure()
        plt.title('decay_rate = {:1f}, counter = {}, average_error = {:1f}, beta = {:1f}'\
                  .format(decay_rate[i,j], counter, average_error[i,j], beta_array[i,j]), fontsize = 10)
        plt.semilogy(np.linspace(0, t_final_array[i,j], 5000), phonon_number_array[i,j], label = 'phonon #', linewidth = 4)
        plt.semilogy(time, best_fit, label = 'phonon fit', linewidth = 3, linestyle = '--', color = '#ff7f0e')
        legend = plt.legend(fontsize = 20, frameon = False)
        plt.xticks(fontsize = 10)
        plt.yticks(fontsize = 10)
        fig = plt.gcf()
        fig.set_size_inches((10, 5), forward=False)
        plt.savefig('./polariton_phonon_decay_thermal/Plot({}, {})'.format(i,j))
        plt.close()

        print('')

decay_rate = decay_rate*beta_array/gamma_function(1/beta_array)
save_data()
# Out:
# ( 0 0 ); oldie error =  0.0
# average error =  0.001192978333991886
#
# ( 0 1 ); oldie error =  0.0
# average error =  0.0017019314227260725
#
# ( 0 2 ); oldie error =  0.0
# average error =  0.0023982496579140118
#
# ( 0 3 ); oldie error =  0.0
# average error =  0.003327177492572421
#
# ( 0 4 ); oldie error =  0.0
# average error =  0.001511036665454062
#
# ( 0 5 ); oldie error =  0.0
# average error =  0.0020155607961385917
#
# ( 0 6 ); oldie error =  0.0
# average error =  0.002626145926083555
#
# ( 0 7 ); oldie error =  0.0
# average error =  0.003331990798589738
#
# ( 0 8 ); oldie error =  0.0
# average error =  0.0041039266006865464
#
# ( 0 9 ); oldie error =  0.0
# average error =  0.004886389129011111
#
# ( 0 10 ); oldie error =  0.0
# average error =  0.0055985878622867805
#
# ( 0 11 ); oldie error =  0.0
# average error =  0.005344578777844053
#
# ( 0 12 ); oldie error =  0.0
# average error =  0.004726598225649799
#
# ( 0 13 ); oldie error =  0.0
# average error =  0.0039023415769697044
#
# ( 0 14 ); oldie error =  0.0
# average error =  0.0029622550968575593
#
# ( 0 15 ); oldie error =  0.0
# average error =  0.002048121425268578
#
# ( 0 16 ); oldie error =  0.0
# average error =  0.0013366682376445276
#
# ( 0 17 ); oldie error =  0.0
# average error =  0.0009400725425014944
#
# ( 0 18 ); oldie error =  0.0
# average error =  0.0008114652677020587
#
# ( 0 19 ); oldie error =  0.0
# average error =  0.0007384343100713504
#
# ( 0 20 ); oldie error =  0.0
# average error =  0.0013593794801322872
#
# ( 0 21 ); oldie error =  0.0
# average error =  0.00013994447331663773
#
# ( 0 22 ); oldie error =  0.0
# average error =  0.00016525559252233721
#
# ( 0 23 ); oldie error =  0.0
# average error =  0.0002286884408229712
#
# ( 0 24 ); oldie error =  0.0
# average error =  0.0001564179229118489
#
# ( 0 25 ); oldie error =  0.0
# average error =  0.00014363363434632726
#
# ( 0 26 ); oldie error =  0.0
# average error =  0.00014014527145364474
#
# ( 0 27 ); oldie error =  0.0
# average error =  0.00013853294591095687
#
# ( 0 28 ); oldie error =  0.0
# average error =  0.0001356441881360024
#
# ( 0 29 ); oldie error =  0.0
# average error =  0.00012961551360997703
#
# ( 1 0 ); oldie error =  0.0
# average error =  0.0018278394878255683
#
# ( 1 1 ); oldie error =  0.0
# average error =  0.002554861761054159
#
# ( 1 2 ); oldie error =  0.0
# average error =  0.0035111831919734803
#
# ( 1 3 ); oldie error =  0.0
# average error =  0.004732154736114132
#
# ( 1 4 ); oldie error =  0.0
# average error =  0.006241516528726304
#
# ( 1 5 ); oldie error =  0.0
# average error =  0.0026805054204542492
#
# ( 1 6 ); oldie error =  0.0
# average error =  0.003367554843157302
#
# ( 1 7 ); oldie error =  0.0
# average error =  0.004116242391586044
#
# ( 1 8 ); oldie error =  0.0
# average error =  0.004885677372739607
#
# ( 1 9 ); oldie error =  0.0
# average error =  0.005617322248970157
#
# ( 1 10 ); oldie error =  0.0
# average error =  0.00623108115958699
#
# ( 1 11 ); oldie error =  0.0
# average error =  0.005782696624362004
#
# ( 1 12 ); oldie error =  0.0
# average error =  0.004997186987789467
#
# ( 1 13 ); oldie error =  0.0
# average error =  0.004065202433240986
#
# ( 1 14 ); oldie error =  0.0
# average error =  0.0030713790785115904
#
# ( 1 15 ); oldie error =  0.0
# average error =  0.0021505061210745323
#
# ( 1 16 ); oldie error =  0.0
# average error =  0.0014517671273083898
#
# ( 1 17 ); oldie error =  0.0
# average error =  0.0032198112740189776
#
# ( 1 18 ); oldie error =  0.0
# average error =  0.0029763034511975307
#
# ( 1 19 ); oldie error =  0.0
# average error =  0.0030229191606024695
#
# ( 1 20 ); oldie error =  0.0
# average error =  0.00210535689947497
#
# ( 1 21 ); oldie error =  0.0
# average error =  0.0007103051833356026
#
# ( 1 22 ); oldie error =  0.0
# average error =  0.0020691268917215487
#
# ( 1 23 ); oldie error =  0.0
# average error =  0.0021689771475152074
#
# ( 1 24 ); oldie error =  0.0
# average error =  0.0004350063472652078
#
# ( 1 25 ); oldie error =  0.0
# average error =  0.00019458132585159488
#
# ( 1 26 ); oldie error =  0.0
# average error =  0.00014299329420709502
#
# ( 1 27 ); oldie error =  0.0
# average error =  0.00041486491328430254
#
# ( 1 28 ); oldie error =  0.0
# average error =  0.0004098939322501976
#
# ( 1 29 ); oldie error =  0.0
# average error =  0.0004002093311066368
#
# ( 2 0 ); oldie error =  0.0
# average error =  0.003975432604994296
#
# ( 2 1 ); oldie error =  0.0
# average error =  0.005396943572240475
#
# ( 2 2 ); oldie error =  0.0
# average error =  0.007181546408015285
#
# ( 2 3 ); oldie error =  0.0
# average error =  0.00935173251414203
#
# ( 2 4 ); oldie error =  0.0
# average error =  0.003965652196068222
#
# ( 2 5 ); oldie error =  0.0
# average error =  0.004923359276533702
#
# ( 2 6 ); oldie error =  0.0
# average error =  0.005958967637479984
#
# ( 2 7 ); oldie error =  0.0
# average error =  0.007026451343494243
#
# ( 2 8 ); oldie error =  0.0
# average error =  0.008064718207505319
#
# ( 2 9 ); oldie error =  0.0
# average error =  0.008991121842342043
#
# ( 2 10 ); oldie error =  0.0
# average error =  0.009712071550478657
#
# ( 2 11 ); oldie error =  0.0
# average error =  0.010107849189281308
#
# ( 2 12 ); oldie error =  0.0
# average error =  0.010067974935641318
#
# ( 2 13 ); oldie error =  0.0
# average error =  0.009505609740622738
#
# ( 2 14 ); oldie error =  0.0
# average error =  0.00842214558896127
#
# ( 2 15 ); oldie error =  0.0
# average error =  0.0064743174821676065
#
# ( 2 16 ); oldie error =  0.0
# average error =  0.004479721292835297
#
# ( 2 17 ); oldie error =  0.0
# average error =  0.0033715765155833354
#
# ( 2 18 ); oldie error =  0.0
# average error =  0.003137352951946853
#
# ( 2 19 ); oldie error =  0.0
# average error =  0.003358852098932772
#
# ( 2 20 ); oldie error =  0.0
# average error =  0.0026965067148760928
#
# ( 2 21 ); oldie error =  0.0
# average error =  0.0010651520137490709
#
# ( 2 22 ); oldie error =  0.0
# average error =  0.0036057479790560258
#
# ( 2 23 ); oldie error =  0.0
# average error =  0.004060005040181084
#
# ( 2 24 ); oldie error =  0.0
# average error =  0.0028650267367335233
#
# ( 2 25 ); oldie error =  0.0
# average error =  0.0014364997312937369
#
# ( 2 26 ); oldie error =  0.0
# average error =  0.0005616754721145902
#
# ( 2 27 ); oldie error =  0.0
# average error =  0.00041936005670219814
#
# ( 2 28 ); oldie error =  0.0
# average error =  0.0004095908779816688
#
# ( 2 29 ); oldie error =  0.0
# average error =  0.0004055403143985349
#
# ( 3 0 ); oldie error =  0.0
# average error =  0.0053745820513088
#
# ( 3 1 ); oldie error =  0.0
# average error =  0.007046372755708674
#
# ( 3 2 ); oldie error =  0.0
# average error =  0.009041286576061954
#
# ( 3 3 ); oldie error =  0.0
# average error =  0.011343311677753641
#
# ( 3 4 ); oldie error =  0.0
# average error =  0.013906439346339141
#
# ( 3 5 ); oldie error =  0.0
# average error =  0.005554736779938163
#
# ( 3 6 ); oldie error =  0.0
# average error =  0.0065022246367157895
#
# ( 3 7 ); oldie error =  0.0
# average error =  0.007439288272114684
#
# ( 3 8 ); oldie error =  0.0
# average error =  0.00831002129724736
#
# ( 3 9 ); oldie error =  0.0
# average error =  0.00904814561597408
#
# ( 3 10 ); oldie error =  0.0
# average error =  0.009576767744542755
#
# ( 3 11 ); oldie error =  0.0
# average error =  0.009809082321214285
#
# ( 3 12 ); oldie error =  0.0
# average error =  0.009663320336626865
#
# ( 3 13 ); oldie error =  0.0
# average error =  0.009085263141596007
#
# ( 3 14 ); oldie error =  0.0
# average error =  0.008094159309151255
#
# ( 3 15 ); oldie error =  0.0
# average error =  0.00631846628881408
#
# ( 3 16 ); oldie error =  0.0
# average error =  0.004450686833788015
#
# ( 3 17 ); oldie error =  0.0
# average error =  0.0033403981693758576
#
# ( 3 18 ); oldie error =  0.0
# average error =  0.0030064476321010145
#
# ( 3 19 ); oldie error =  0.0
# average error =  0.0032017947015047852
#
# ( 3 20 ); oldie error =  0.0
# average error =  0.002925845706497843
#
# ( 3 21 ); oldie error =  0.0
# average error =  0.0013852807289967525
#
# ( 3 22 ); oldie error =  0.0
# average error =  0.0045284220800116464
#
# ( 3 23 ); oldie error =  0.0
# average error =  0.005672561600984447
#
# ( 3 24 ); oldie error =  0.0
# average error =  0.004613998116647629
#
# ( 3 25 ); oldie error =  0.0
# average error =  0.00279580024709952
#
# ( 3 26 ); oldie error =  0.0
# average error =  0.001243512465743003
#
# ( 3 27 ); oldie error =  0.0
# average error =  0.00047405158833693746
#
# ( 3 28 ); oldie error =  0.0
# average error =  0.0004095220073202902
#
# ( 3 29 ); oldie error =  0.0
# average error =  0.00040514740980637543
#
# ( 4 0 ); oldie error =  0.0
# average error =  0.006718206448295226
# ( 4 1 ); oldie error =  0.0
# average error =  0.008481597207880076
#
# ( 4 2 ); oldie error =  0.0
# average error =  0.010480574907587073
#
# ( 4 3 ); oldie error =  0.0
# average error =  0.012686220345139733
#
# ( 4 4 ); oldie error =  0.0
# average error =  0.015044089504338894
#
# ( 4 5 ); oldie error =  0.0
# average error =  0.017493579696952224
#
# ( 4 6 ); oldie error =  0.0
# average error =  0.019945444689898464
#
# ( 4 7 ); oldie error =  0.0
# average error =  0.0074358699886162664
#
# ( 4 8 ); oldie error =  0.0
# average error =  0.008143533617307491
#
# ( 4 9 ); oldie error =  0.0
# average error =  0.008718809228642672
#
# ( 4 10 ); oldie error =  0.0
# average error =  0.009102748920567047
#
# ( 4 11 ); oldie error =  0.0
# average error =  0.009233108218821097
#
# ( 4 12 ); oldie error =  0.0
# average error =  0.009054060704366592
#
# ( 4 13 ); oldie error =  0.0
# average error =  0.008524937646523045
#
# ( 4 14 ); oldie error =  0.0
# average error =  0.007670522314654494
#
# ( 4 15 ); oldie error =  0.0
# average error =  0.006095198454374111
#
# ( 4 16 ); oldie error =  0.0
# average error =  0.00436091970273843
#
# ( 4 17 ); oldie error =  0.0
# average error =  0.0032354494195701365
#
# ( 4 18 ); oldie error =  0.0
# average error =  0.0027545412723026493
#
# ( 4 19 ); oldie error =  0.0
# average error =  0.00835135431160568
#
# ( 4 20 ); oldie error =  0.0
# average error =  0.008273418917412078
#
# ( 4 21 ); oldie error =  0.0
# average error =  0.0046353969245612
#
# ( 4 22 ); oldie error =  0.0
# average error =  0.014348029173713818
#
# ( 4 23 ); oldie error =  0.0
# average error =  0.019883505217124443
#
# ( 4 24 ); oldie error =  0.0
# average error =  0.0060455876010390664
#
# ( 4 25 ); oldie error =  0.0
# average error =  0.004260563253469791
#
# ( 4 26 ); oldie error =  0.0
# average error =  0.0023202229245336313
#
# ( 4 27 ); oldie error =  0.0
# average error =  0.0009253774371613506
#
# ( 4 28 ); oldie error =  0.0
# average error =  0.00041608961398075515
#
# ( 4 29 ); oldie error =  0.0
# average error =  0.0004019678276303198
#
# ( 5 0 ); oldie error =  0.0
# average error =  0.007740158980119833
#
# ( 5 1 ); oldie error =  0.0
# average error =  0.009420187835771575
#
# ( 5 2 ); oldie error =  0.0
# average error =  0.01125564840798563
#
# ( 5 3 ); oldie error =  0.0
# average error =  0.013212458080037976
#
# ( 5 4 ); oldie error =  0.0
# average error =  0.01525572260605199
#
# ( 5 5 ); oldie error =  0.0
# average error =  0.0173383989871964
#
# ( 5 6 ); oldie error =  0.0
# average error =  0.019394683901660683
#
# ( 5 7 ); oldie error =  0.0
# average error =  0.02133586681501002
#
# ( 5 8 ); oldie error =  0.0
# average error =  0.023059672122464122
#
# ( 5 9 ); oldie error =  0.0
# average error =  0.008146006088277282
#
# ( 5 10 ); oldie error =  0.0
# average error =  0.008444665963797419
#
# ( 5 11 ); oldie error =  0.0
# average error =  0.008534316621424148
#
# ( 5 12 ); oldie error =  0.0
# average error =  0.008377167858954412
#
# ( 5 13 ); oldie error =  0.0
# average error =  0.007951403429908863
#
# ( 5 14 ); oldie error =  0.0
# average error =  0.007261104033774376
#
# ( 5 15 ); oldie error =  0.0
# average error =  0.0058866362840999005
#
# ( 5 16 ); oldie error =  0.0
# average error =  0.004280306969214681
#
# ( 5 17 ); oldie error =  0.0
# average error =  0.009428035506268072
#
# ( 5 18 ); oldie error =  0.0
# average error =  0.007553841475378706
#
# ( 5 19 ); oldie error =  0.0
# average error =  0.0070215916032090745
#
# ( 5 20 ); oldie error =  0.0
# average error =  0.00691791450131007
#
# ( 5 21 ); oldie error =  0.0
# average error =  0.004502794440735656
#
# ( 5 22 ); oldie error =  0.0
# average error =  0.01374990174567404
#
# ( 5 23 ); oldie error =  0.0
# average error =  0.020715807921076575
#
# ( 5 24 ); oldie error =  0.0
# average error =  0.02064782271119554
#
# ( 5 25 ); oldie error =  0.0
# average error =  0.005449374126489938
#
# ( 5 26 ); oldie error =  0.0
# average error =  0.0034839017104351107
#
# ( 5 27 ); oldie error =  0.0
# average error =  0.00171683618038425
#
# ( 5 28 ); oldie error =  0.0
# average error =  0.000626812093599884
#
# ( 5 29 ); oldie error =  0.0
# average error =  0.0003999990513847924
#
# ( 6 0 ); oldie error =  0.0
# average error =  0.008264373536609923
#
# ( 6 1 ); oldie error =  0.0
# average error =  0.009750711272400491
#
# ( 6 2 ); oldie error =  0.0
# average error =  0.01133481596419729
#
# ( 6 3 ); oldie error =  0.0
# average error =  0.012994937149939736
#
# ( 6 4 ); oldie error =  0.0
# average error =  0.014709549792475303
#
# ( 6 5 ); oldie error =  0.0
# average error =  0.01643821803542715
#
# ( 6 6 ); oldie error =  0.0
# average error =  0.01813894508004897
#
# ( 6 7 ); oldie error =  0.0
# average error =  0.019746969723999457
#
# ( 6 8 ); oldie error =  0.0
# average error =  0.02118593621232142
#
# ( 6 9 ); oldie error =  0.0
# average error =  0.022352020251033847
#
# ( 6 10 ); oldie error =  0.0
# average error =  0.023147187072922452
#
# ( 6 11 ); oldie error =  0.0
# average error =  0.0234610390904078
#
# ( 6 12 ); oldie error =  0.0
# average error =  0.02319690512303201
#
# ( 6 13 ); oldie error =  0.0
# average error =  0.02229248718489192
#
# ( 6 14 ); oldie error =  0.0
# average error =  0.020725965383779875
#
# ( 6 15 ); oldie error =  0.0
# average error =  0.01716942454733652
#
# ( 6 16 ); oldie error =  0.0
# average error =  0.012707517192114307
#
# ( 6 17 ); oldie error =  0.0
# average error =  0.009291932596568147
#
# ( 6 18 ); oldie error =  0.0
# average error =  0.007075844193200512
#
# ( 6 19 ); oldie error =  0.0
# average error =  0.0059891736600180085
#
# ( 6 20 ); oldie error =  0.0
# average error =  0.005457728551818638
#
# ( 6 21 ); oldie error =  0.0
# average error =  0.003882972274192116
#
# ( 6 22 ); oldie error =  0.0
# average error =  0.012496510645220152
#
# ( 6 23 ); oldie error =  0.0
# average error =  0.020043509524284474
#
# ( 6 24 ); oldie error =  0.0
# average error =  0.021345088218723777
#
# ( 6 25 ); oldie error =  0.0
# average error =  0.018450075069156354
#
# ( 6 26 ); oldie error =  0.0
# average error =  0.004443124384013291
#
# ( 6 27 ); oldie error =  0.0
# average error =  0.0026084214600751695
#
# ( 6 28 ); oldie error =  0.0
# average error =  0.0011546691285116892
#
# ( 6 29 ); oldie error =  0.0
# average error =  0.00043443967192170085
#
# ( 7 0 ); oldie error =  0.0
# average error =  0.008270970397693419
#
# ( 7 1 ); oldie error =  0.0
# average error =  0.009523765502176025
#
# ( 7 2 ); oldie error =  0.0
# average error =  0.010848095303778092
#
# ( 7 3 ); oldie error =  0.0
# average error =  0.01221385678092891
#
# ( 7 4 ); oldie error =  0.0
# average error =  0.013630268457386558
#
# ( 7 5 ); oldie error =  0.0
# average error =  0.015059730520166365
#
# ( 7 6 ); oldie error =  0.0
# average error =  0.01647699261353407
#
# ( 7 7 ); oldie error =  0.0
# average error =  0.017844541626540304
#
# ( 7 8 ); oldie error =  0.0
# average error =  0.0190950255181341
#
# ( 7 9 ); oldie error =  0.0
# average error =  0.020177387975347377
#
# ( 7 10 ); oldie error =  0.0
# average error =  0.02098483361155002
#
# ( 7 11 ); oldie error =  0.0
# average error =  0.021437023544483003
#
# ( 7 12 ); oldie error =  0.0
# average error =  0.021447143000572065
#
# ( 7 13 ); oldie error =  0.0
# average error =  0.020928771295332934
#
# ( 7 14 ); oldie error =  0.0
# average error =  0.019828612497273787
#
# ( 7 15 ); oldie error =  0.0
# average error =  0.0167578928662977
#
# ( 7 16 ); oldie error =  0.0
# average error =  0.012618325178211447
#
# ( 7 17 ); oldie error =  0.0
# average error =  0.009244693077490521
#
# ( 7 18 ); oldie error =  0.0
# average error =  0.0068015959920272265
#
# ( 7 19 ); oldie error =  0.0
# average error =  0.0053033371882158864
#
# ( 7 20 ); oldie error =  0.0
# average error =  0.004388802780632534
#
# ( 7 21 ); oldie error =  0.0
# average error =  0.003027088861359845
#
# ( 7 22 ); oldie error =  0.0
# average error =  0.011064611492041007
#
# ( 7 23 ); oldie error =  0.0
# average error =  0.01847785177829569
#
# ( 7 24 ); oldie error =  0.0
# average error =  0.02064574437592518
#
# ( 7 25 ); oldie error =  0.0
# average error =  0.019040783720601313
#
# ( 7 26 ); oldie error =  0.0
# average error =  0.015085499630624083
#
# ( 7 27 ); oldie error =  0.0
# average error =  0.003373535025056295
#
# ( 7 28 ); oldie error =  0.0
# average error =  0.0018118862662105386
#
# ( 7 29 ); oldie error =  0.0
# average error =  0.0007195209687416953
#
# ( 8 0 ); oldie error =  0.0
# average error =  0.007840112315427422
#
# ( 8 1 ); oldie error =  0.0
# average error =  0.008869854921601217
#
# ( 8 2 ); oldie error =  0.0
# average error =  0.009948934639472707
# ( 8 3 ); oldie error =  0.0
# average error =  0.011073003206579727
#
# ( 8 4 ); oldie error =  0.0
# average error =  0.012240442128482805
#
# ( 8 5 ); oldie error =  0.0
# average error =  0.013434713374755727
#
# ( 8 6 ); oldie error =  0.0
# average error =  0.014648155187107338
#
# ( 8 7 ); oldie error =  0.0
# average error =  0.015851043174150047
#
# ( 8 8 ); oldie error =  0.0
# average error =  0.017006616096659134
#
# ( 8 9 ); oldie error =  0.0
# average error =  0.01806411825303769
#
# ( 8 10 ); oldie error =  0.0
# average error =  0.018942815823143663
#
# ( 8 11 ); oldie error =  0.0
# average error =  0.019569903594108644
#
# ( 8 12 ); oldie error =  0.0
# average error =  0.0198348605081306
#
# ( 8 13 ); oldie error =  0.0
# average error =  0.019643955404573143
#
# ( 8 14 ); oldie error =  0.0
# average error =  0.018910626748602548
#
# ( 8 15 ); oldie error =  0.0
# average error =  0.016263214916026097
#
# ( 8 16 ); oldie error =  0.0
# average error =  0.012425419448068832
#
# ( 8 17 ); oldie error =  0.0
# average error =  0.009152304695018581
#
# ( 8 18 ); oldie error =  0.0
# average error =  0.006605935437204858
#
# ( 8 19 ); oldie error =  0.0
# average error =  0.004852991668056389
#
# ( 8 20 ); oldie error =  0.0
# average error =  0.0036705329291356493
#
# ( 8 21 ); oldie error =  0.0
# average error =  0.002350340097460759
#
# ( 8 22 ); oldie error =  0.0
# average error =  0.009696711980682208
#
# ( 8 23 ); oldie error =  0.0
# average error =  0.01650301635814639
#
# ( 8 24 ); oldie error =  0.0
# average error =  0.01905965388993343
#
# ( 8 25 ); oldie error =  0.0
# average error =  0.018425275954729467
#
# ( 8 26 ); oldie error =  0.0
# average error =  0.015637710435621257
#
# ( 8 27 ); oldie error =  0.0
# average error =  0.0038691720062265303
#
# ( 8 28 ); oldie error =  0.0
# average error =  0.0024143306643257183
#
# ( 8 29 ); oldie error =  0.0
# average error =  0.0011705432672471216
#
# ( 9 0 ); oldie error =  0.0
# average error =  0.007094558657553765
#
# ( 9 1 ); oldie error =  0.0
# average error =  0.007926334939562369
#
# ( 9 2 ); oldie error =  0.0
# average error =  0.008805379272426228
#
# ( 9 3 ); oldie error =  0.0
# average error =  0.009732623930328265
#
# ( 9 4 ); oldie error =  0.0
# average error =  0.010711917302792221
#
# ( 9 5 ); oldie error =  0.0
# average error =  0.01173255834677487
#
# ( 9 6 ); oldie error =  0.0
# average error =  0.012810398411567264
#
# ( 9 7 ); oldie error =  0.0
# average error =  0.013901719079451303
#
# ( 9 8 ); oldie error =  0.0
# average error =  0.015006754616503167
#
# ( 9 9 ); oldie error =  0.0
# average error =  0.016057656854596137
#
# ( 9 10 ); oldie error =  0.0
# average error =  0.01701364775419922
#
# ( 9 11 ); oldie error =  0.0
# average error =  0.017759896939559865
#
# ( 9 12 ); oldie error =  0.0
# average error =  0.018227116272260615
#
# ( 9 13 ); oldie error =  0.0
# average error =  0.01825440497992258
#
# ( 9 14 ); oldie error =  0.0
# average error =  0.017797910614893078
#
# ( 9 15 ); oldie error =  0.0
# average error =  0.01548983838513727
#
# ( 9 16 ); oldie error =  0.0
# average error =  0.011965594851912066
#
# ( 9 17 ); oldie error =  0.0
# average error =  0.008866833113767271
#
# ( 9 18 ); oldie error =  0.0
# average error =  0.006353214958274049
#
# ( 9 19 ); oldie error =  0.0
# average error =  0.004497105180052971
#
# ( 9 20 ); oldie error =  0.0
# average error =  0.0031749136424288377
#
# ( 9 21 ); oldie error =  0.0
# average error =  0.0018960188473559295
#
# ( 9 22 ); oldie error =  0.0
# average error =  0.008487281353117559
#
# ( 9 23 ); oldie error =  0.0
# average error =  0.014442041662842246
#
# ( 9 24 ); oldie error =  0.0
# average error =  0.01702258874794988
#
# ( 9 25 ); oldie error =  0.0
# average error =  0.017015458822129074
#
# ( 9 26 ); oldie error =  0.0
# average error =  0.015195578122899588
#
# ( 9 27 ); oldie error =  0.0
# average error =  0.012172478664456681
#
# ( 9 28 ); oldie error =  0.0
# average error =  0.0028372571136770462
#
# ( 9 29 ); oldie error =  0.0
# average error =  0.0016314169793694238
#
# ( 10 0 ); oldie error =  0.0
# average error =  0.006143521857922721
#
# ( 10 1 ); oldie error =  0.0
# average error =  0.006820808018180223
#
# ( 10 2 ); oldie error =  0.0
# average error =  0.007534420677216461
#
# ( 10 3 ); oldie error =  0.0
# average error =  0.008319809414229818
#
# ( 10 4 ); oldie error =  0.0
# average error =  0.009154894205930401
#
# ( 10 5 ); oldie error =  0.0
# average error =  0.010069134163271338
#
# ( 10 6 ); oldie error =  0.0
# average error =  0.011034745648171104
#
# ( 10 7 ); oldie error =  0.0
# average error =  0.012053982311935472
#
# ( 10 8 ); oldie error =  0.0
# average error =  0.013110123760783868
#
# ( 10 9 ); oldie error =  0.0
# average error =  0.014147108622096971
#
# ( 10 10 ); oldie error =  0.0
# average error =  0.015099355952966161
#
# ( 10 11 ); oldie error =  0.0
# average error =  0.015908380693591
#
# ( 10 12 ); oldie error =  0.0
# average error =  0.016449960128916554
#
# ( 10 13 ); oldie error =  0.0
# average error =  0.016617318732501645
#
# ( 10 14 ); oldie error =  0.0
# average error =  0.016324564048605345
#
# ( 10 15 ); oldie error =  0.0
# average error =  0.014320861099723805
#
# ( 10 16 ); oldie error =  0.0
# average error =  0.011151203820485376
#
# ( 10 17 ); oldie error =  0.0
# average error =  0.008321763008009969
#
# ( 10 18 ); oldie error =  0.0
# average error =  0.005955851495197859
#
# ( 10 19 ); oldie error =  0.0
# average error =  0.004135784865824305
#
# ( 10 20 ); oldie error =  0.0
# average error =  0.00278848019263719
#
# ( 10 21 ); oldie error =  0.0
# average error =  0.0015791148184380324
#
# ( 10 22 ); oldie error =  0.0
# average error =  0.007456957230240407
#
# ( 10 23 ); oldie error =  0.0
# average error =  0.012462395503798756
#
# ( 10 24 ); oldie error =  0.0
# average error =  0.014847639600874526
#
# ( 10 25 ); oldie error =  0.0
# average error =  0.015179887344477163
#
# ( 10 26 ); oldie error =  0.0
# average error =  0.0140727189913632
#
# ( 10 27 ); oldie error =  0.0
# average error =  0.011941244744851889
#
# ( 10 28 ); oldie error =  0.0
# average error =  0.009103807991651424
#
# ( 10 29 ); oldie error =  0.0
# average error =  0.0019892348514945844
#
# ( 11 0 ); oldie error =  0.0
# average error =  0.005088274238989019
#
# ( 11 1 ); oldie error =  0.0
# average error =  0.0056445422731947045
#
# ( 11 2 ); oldie error =  0.0
# average error =  0.006254074944720346
#
# ( 11 3 ); oldie error =  0.0
# average error =  0.006923754854535551
#
# ( 11 4 ); oldie error =  0.0
# average error =  0.0076631826413853955
#
# ( 11 5 ); oldie error =  0.0
# average error =  0.008474227555246001
#
# ( 11 6 ); oldie error =  0.0
# average error =  0.00934809676028708
#
# ( 11 7 ); oldie error =  0.0
# average error =  0.010279655454831865
#
# ( 11 8 ); oldie error =  0.0
# average error =  0.011261221799771928
#
# ( 11 9 ); oldie error =  0.0
# average error =  0.01222248489249816
#
# ( 11 10 ); oldie error =  0.0
# average error =  0.013126141975034613
#
# ( 11 11 ); oldie error =  0.0
# average error =  0.01389540668659975
#
# ( 11 12 ); oldie error =  0.0
# average error =  0.014411565299966839
#
# ( 11 13 ); oldie error =  0.0
# average error =  0.01463466496496888
#
# ( 11 14 ); oldie error =  0.0
# average error =  0.014445250007643875
#
# ( 11 15 ); oldie error =  0.0
# average error =  0.012748382492447266
#
# ( 11 16 ); oldie error =  0.0
# average error =  0.009994958640688176
#
# ( 11 17 ); oldie error =  0.0
# average error =  0.007509892009118717
#
# ( 11 18 ); oldie error =  0.0
# average error =  0.005395474176835383
#
# ( 11 19 ); oldie error =  0.0
# average error =  0.0037204717820978972
#
# ( 11 20 ); oldie error =  0.0
# average error =  0.002441627942022965
#
# ( 11 21 ); oldie error =  0.0
# average error =  0.0014276143816825341
#
# ( 11 22 ); oldie error =  0.0
# average error =  0.006593327784636571
#
# ( 11 23 ); oldie error =  0.0
# average error =  0.010661045362895834
#
# ( 11 24 ); oldie error =  0.0
# average error =  0.012724201188728737
#
# ( 11 25 ); oldie error =  0.0
# average error =  0.01318980173689682
#
# ( 11 26 ); oldie error =  0.0
# average error =  0.012566539248109564
#
# ( 11 27 ); oldie error =  0.0
# average error =  0.011137748179081893
#
# ( 11 28 ); oldie error =  0.0
# average error =  0.009071479849562693
#
# ( 11 29 ); oldie error =  0.0
# average error =  0.00656885620662412
#
# ( 12 0 ); oldie error =  0.0
# average error =  0.0040267561026302995
#
# ( 12 1 ); oldie error =  0.0
# average error =  0.004497979577354563
#
# ( 12 2 ); oldie error =  0.0
# average error =  0.005020840914836705
#
# ( 12 3 ); oldie error =  0.0
# average error =  0.0056012940357511405
#
# ( 12 4 ); oldie error =  0.0
# average error =  0.006250934452870409
# ( 12 5 ); oldie error =  0.0
# average error =  0.006963196796714298
#
# ( 12 6 ); oldie error =  0.0
# average error =  0.007743694244666446
#
# ( 12 7 ); oldie error =  0.0
# average error =  0.008573752330729123
#
# ( 12 8 ); oldie error =  0.0
# average error =  0.009416214587564668
#
# ( 12 9 ); oldie error =  0.0
# average error =  0.010253218747604036
#
# ( 12 10 ); oldie error =  0.0
# average error =  0.011006847689179079
#
# ( 12 11 ); oldie error =  0.0
# average error =  0.011679158992423024
#
# ( 12 12 ); oldie error =  0.0
# average error =  0.012139479949574013
#
# ( 12 13 ); oldie error =  0.0
# average error =  0.012356799898000549
#
# ( 12 14 ); oldie error =  0.0
# average error =  0.012254026317999243
#
# ( 12 15 ); oldie error =  0.0
# average error =  0.01084671294392649
#
# ( 12 16 ); oldie error =  0.0
# average error =  0.008573735102241957
#
# ( 12 17 ); oldie error =  0.0
# average error =  0.0064877977496932875
#
# ( 12 18 ); oldie error =  0.0
# average error =  0.0046967121341399565
#
# ( 12 19 ); oldie error =  0.0
# average error =  0.0032434956764362147
#
# ( 12 20 ); oldie error =  0.0
# average error =  0.002096647715489897
#
# ( 12 21 ); oldie error =  0.0
# average error =  0.0015228067882493996
#
# ( 12 22 ); oldie error =  0.0
# average error =  0.005873606733106956
#
# ( 12 23 ); oldie error =  0.0
# average error =  0.009081117643280229
#
# ( 12 24 ); oldie error =  0.0
# average error =  0.010760708309014808
#
# ( 12 25 ); oldie error =  0.0
# average error =  0.011236836160830618
#
# ( 12 26 ); oldie error =  0.0
# average error =  0.010912613818938488
#
# ( 12 27 ); oldie error =  0.0
# average error =  0.009996900940868863
#
# ( 12 28 ); oldie error =  0.0
# average error =  0.008566406920185224
#
# ( 12 29 ); oldie error =  0.0
# average error =  0.006694910612509037
#
# ( 13 0 ); oldie error =  0.0
# average error =  0.0030584741916055832
#
# ( 13 1 ); oldie error =  0.0
# average error =  0.003447773524493473
#
# ( 13 2 ); oldie error =  0.0
# average error =  0.0038902341023848543
#
# ( 13 3 ); oldie error =  0.0
# average error =  0.0043875841855105365
#
# ( 13 4 ); oldie error =  0.0
# average error =  0.004937895054242229
#
# ( 13 5 ); oldie error =  0.0
# average error =  0.00554165729940228
#
# ( 13 6 ); oldie error =  0.0
# average error =  0.006188844253373669
#
# ( 13 7 ); oldie error =  0.0
# average error =  0.006871339367880054
#
# ( 13 8 ); oldie error =  0.0
# average error =  0.007568797913987531
#
# ( 13 9 ); oldie error =  0.0
# average error =  0.008238446181976358
#
# ( 13 10 ); oldie error =  0.0
# average error =  0.008866769100744869
#
# ( 13 11 ); oldie error =  0.0
# average error =  0.009398182518865277
#
# ( 13 12 ); oldie error =  0.0
# average error =  0.009769651633242976
#
# ( 13 13 ); oldie error =  0.0
# average error =  0.009952363536130333
#
# ( 13 14 ); oldie error =  0.0
# average error =  0.009888807460731456
#
# ( 13 15 ); oldie error =  0.0
# average error =  0.008816013472294562
#
# ( 13 16 ); oldie error =  0.0
# average error =  0.007005718413617599
#
# ( 13 17 ); oldie error =  0.0
# average error =  0.005360512077165953
#
# ( 13 18 ); oldie error =  0.0
# average error =  0.00391347490076582
#
# ( 13 19 ); oldie error =  0.0
# average error =  0.002714860972752963
#
# ( 13 20 ); oldie error =  0.0
# average error =  0.0017479602900952955
#
# ( 13 21 ); oldie error =  0.0
# average error =  0.0018878828958765123
#
# ( 13 22 ); oldie error =  0.0
# average error =  0.005265950147458087
#
# ( 13 23 ); oldie error =  0.0
# average error =  0.007709839953583996
#
# ( 13 24 ); oldie error =  0.0
# average error =  0.009002865552810187
#
# ( 13 25 ); oldie error =  0.0
# average error =  0.009420627689378486
#
# ( 13 26 ); oldie error =  0.0
# average error =  0.009275302789415244
#
# ( 13 27 ); oldie error =  0.0
# average error =  0.008710034189119784
#
# ( 13 28 ); oldie error =  0.0
# average error =  0.007761158808109254
#
# ( 13 29 ); oldie error =  0.0
# average error =  0.006433818497297935
#
# ( 14 0 ); oldie error =  0.0
# average error =  0.0022091357059524645
#
# ( 14 1 ); oldie error =  0.0
# average error =  0.0025261917275817168
#
# ( 14 2 ); oldie error =  0.0
# average error =  0.002885248928530307
#
# ( 14 3 ); oldie error =  0.0
# average error =  0.0032871866447665554
#
# ( 14 4 ); oldie error =  0.0
# average error =  0.0037319498877975915
#
# ( 14 5 ); oldie error =  0.0
# average error =  0.004206258753846728
#
# ( 14 6 ); oldie error =  0.0
# average error =  0.0047102787526197756
#
# ( 14 7 ); oldie error =  0.0
# average error =  0.005238063471821997
#
# ( 14 8 ); oldie error =  0.0
# average error =  0.005757898549988791
#
# ( 14 9 ); oldie error =  0.0
# average error =  0.0062764587013687655
#
# ( 14 10 ); oldie error =  0.0
# average error =  0.006752176580183564
#
# ( 14 11 ); oldie error =  0.0
# average error =  0.00714265699959836
#
# ( 14 12 ); oldie error =  0.0
# average error =  0.007443303031602414
#
# ( 14 13 ); oldie error =  0.0
# average error =  0.007601180537042583
#
# ( 14 14 ); oldie error =  0.0
# average error =  0.007576815229024537
#
# ( 14 15 ); oldie error =  0.0
# average error =  0.006786195927383204
#
# ( 14 16 ); oldie error =  0.0
# average error =  0.005449811899029052
#
# ( 14 17 ); oldie error =  0.0
# average error =  0.004209212734077729
#
# ( 14 18 ); oldie error =  0.0
# average error =  0.0031158681918483635
#
# ( 14 19 ); oldie error =  0.0
# average error =  0.0021767070567983815
#
# ( 14 20 ); oldie error =  0.0
# average error =  0.0013936512980464418
#
# ( 14 21 ); oldie error =  0.0
# average error =  0.0022491390296478187
#
# ( 14 22 ); oldie error =  0.0
# average error =  0.00475081223984714
#
# ( 14 23 ); oldie error =  0.0
# average error =  0.0065379621199147695
#
# ( 14 24 ); oldie error =  0.0
# average error =  0.007474226861686543
#
# ( 14 25 ); oldie error =  0.0
# average error =  0.0077955041814435745
#
# ( 14 26 ); oldie error =  0.0
# average error =  0.007745892066416347
#
# ( 14 27 ); oldie error =  0.0
# average error =  0.007413809854591523
#
# ( 14 28 ); oldie error =  0.0
# average error =  0.006810306630996979
#
# ( 14 29 ); oldie error =  0.0
# average error =  0.005910001960419261
#
# ( 15 0 ); oldie error =  0.0
# average error =  0.0015024865191550984
#
# ( 15 1 ); oldie error =  0.0
# average error =  0.00174135885256762
#
# ( 15 2 ); oldie error =  0.0
# average error =  0.0020102090004263007
#
# ( 15 3 ); oldie error =  0.0
# average error =  0.0023114773527863493
#
# ( 15 4 ); oldie error =  0.0
# average error =  0.002637189575748615
#
# ( 15 5 ); oldie error =  0.0
# average error =  0.002985221274270949
#
# ( 15 6 ); oldie error =  0.0
# average error =  0.003355445125063629
#
# ( 15 7 ); oldie error =  0.0
# average error =  0.0037327111010851126
#
# ( 15 8 ); oldie error =  0.0
# average error =  0.00411262757788933
#
# ( 15 9 ); oldie error =  0.0
# average error =  0.004474029098162527
#
# ( 15 10 ); oldie error =  0.0
# average error =  0.004812193464650992
#
# ( 15 11 ); oldie error =  0.0
# average error =  0.005095377440685107
#
# ( 15 12 ); oldie error =  0.0
# average error =  0.0053302760216575205
#
# ( 15 13 ); oldie error =  0.0
# average error =  0.005466525257526436
#
# ( 15 14 ); oldie error =  0.0
# average error =  0.005483091196143089
#
# ( 15 15 ); oldie error =  0.0
# average error =  0.004950605793901222
#
# ( 15 16 ); oldie error =  0.0
# average error =  0.004017126949482553
#
# ( 15 17 ); oldie error =  0.0
# average error =  0.003129754033366502
#
# ( 15 18 ); oldie error =  0.0
# average error =  0.002349469034488034
#
# ( 15 19 ); oldie error =  0.0
# average error =  0.0016500497928411413
#
# ( 15 20 ); oldie error =  0.0
# average error =  0.0010596423903493383
#
# ( 15 21 ); oldie error =  0.0
# average error =  0.0025149438340945456
#
# ( 15 22 ); oldie error =  0.0
# average error =  0.004293195306271147
#
# ( 15 23 ); oldie error =  0.0
# average error =  0.005527944240531351
#
# ( 15 24 ); oldie error =  0.0
# average error =  0.006156490981425144
#
# ( 15 25 ); oldie error =  0.0
# average error =  0.006386921986726156
#
# ( 15 26 ); oldie error =  0.0
# average error =  0.006379577420617109
#
# ( 15 27 ); oldie error =  0.0
# average error =  0.006197150046717578
#
# ( 15 28 ); oldie error =  0.0
# average error =  0.00582762154218937
#
# ( 15 29 ); oldie error =  0.0
# average error =  0.00524110635999242
#
# ( 16 0 ); oldie error =  0.0
# average error =  0.0009626363104647588
#
# ( 16 1 ); oldie error =  0.0
# average error =  0.0011214116518191825
#
# ( 16 2 ); oldie error =  0.0
# average error =  0.0013010003519850365
#
# ( 16 3 ); oldie error =  0.0
# average error =  0.001497583312042639
# ( 16 4 ); oldie error =  0.0
# average error =  0.0017168869976126224
#
# ( 16 5 ); oldie error =  0.0
# average error =  0.0019468337807683894
#
# ( 16 6 ); oldie error =  0.0
# average error =  0.00218759389368613
#
# ( 16 7 ); oldie error =  0.0
# average error =  0.002443962967645197
#
# ( 16 8 ); oldie error =  0.0
# average error =  0.002701288531548876
#
# ( 16 9 ); oldie error =  0.0
# average error =  0.002943960339872077
#
# ( 16 10 ); oldie error =  0.0
# average error =  0.0031782581006428827
#
# ( 16 11 ); oldie error =  0.0
# average error =  0.0033836689532954402
#
# ( 16 12 ); oldie error =  0.0
# average error =  0.0035517637588876193
#
# ( 16 13 ); oldie error =  0.0
# average error =  0.0036646987394072413
#
# ( 16 14 ); oldie error =  0.0
# average error =  0.0037013060863665364
#
# ( 16 15 ); oldie error =  0.0
# average error =  0.003382087228243612
#
# ( 16 16 ); oldie error =  0.0
# average error =  0.0027623367568424206
#
# ( 16 17 ); oldie error =  0.0
# average error =  0.002187741222747307
#
# ( 16 18 ); oldie error =  0.0
# average error =  0.0016480179694567869
#
# ( 16 19 ); oldie error =  0.0
# average error =  0.001163633197050959
#
# ( 16 20 ); oldie error =  0.0
# average error =  0.0012420316551715776
#
# ( 16 21 ); oldie error =  0.0
# average error =  0.0026813014970039142
#
# ( 16 22 ); oldie error =  0.0
# average error =  0.0038720172479256333
#
# ( 16 23 ); oldie error =  0.0
# average error =  0.00465974829091141
#
# ( 16 24 ); oldie error =  0.0
# average error =  0.005041214920436052
#
# ( 16 25 ); oldie error =  0.0
# average error =  0.005178578790323821
#
# ( 16 26 ); oldie error =  0.0
# average error =  0.005194601821360496
#
# ( 16 27 ); oldie error =  0.0
# average error =  0.0051025880921429685
#
# ( 16 28 ); oldie error =  0.0
# average error =  0.004888282506302229
#
# ( 16 29 ); oldie error =  0.0
# average error =  0.004520975602493571
#
# ( 17 0 ); oldie error =  0.0
# average error =  0.0005897046365259818
#
# ( 17 1 ); oldie error =  0.0
# average error =  0.0006813171300539857
#
# ( 17 2 ); oldie error =  0.0
# average error =  0.0007820964668645002
#
# ( 17 3 ); oldie error =  0.0
# average error =  0.0008949390352902014
#
# ( 17 4 ); oldie error =  0.0
# average error =  0.0010222378580645156
#
# ( 17 5 ); oldie error =  0.0
# average error =  0.0011575751792853855
#
# ( 17 6 ); oldie error =  0.0
# average error =  0.0012965716679277461
#
# ( 17 7 ); oldie error =  0.0
# average error =  0.0014485928198689302
#
# ( 17 8 ); oldie error =  0.0
# average error =  0.0016058085268364898
#
# ( 17 9 ); oldie error =  0.0
# average error =  0.00175393646539465
#
# ( 17 10 ); oldie error =  0.0
# average error =  0.0019027875433165462
#
# ( 17 11 ); oldie error =  0.0
# average error =  0.0020409424313904342
#
# ( 17 12 ); oldie error =  0.0
# average error =  0.002149389977280588
#
# ( 17 13 ); oldie error =  0.0
# average error =  0.0022451620400278627
#
# ( 17 14 ); oldie error =  0.0
# average error =  0.0022901061935029217
#
# ( 17 15 ); oldie error =  0.0
# average error =  0.0021115200741488953
#
# ( 17 16 ); oldie error =  0.0
# average error =  0.001742356075332026
#
# ( 17 17 ); oldie error =  0.0
# average error =  0.001394162305828303
#
# ( 17 18 ); oldie error =  0.0
# average error =  0.001053393496215739
#
# ( 17 19 ); oldie error =  0.0
# average error =  0.0008700431070399522
#
# ( 17 20 ); oldie error =  0.0
# average error =  0.0018087171038536074
#
# ( 17 21 ); oldie error =  0.0
# average error =  0.0027452930093855702
#
# ( 17 22 ); oldie error =  0.0
# average error =  0.0034627715313718384
#
# ( 17 23 ); oldie error =  0.0
# average error =  0.0038941614541564717
#
# ( 17 24 ); oldie error =  0.0
# average error =  0.0040892135421691424
#
# ( 17 25 ); oldie error =  0.0
# average error =  0.0041622396754258375
#
# ( 17 26 ); oldie error =  0.0
# average error =  0.0041851452306889666
#
# ( 17 27 ); oldie error =  0.0
# average error =  0.004148359269699518
#
# ( 17 28 ); oldie error =  0.0
# average error =  0.004034957841023958
#
# ( 17 29 ); oldie error =  0.0
# average error =  0.0038160722140236627
#
# ( 18 0 ); oldie error =  0.0
# average error =  0.00036040165507459667
#
# ( 18 1 ); oldie error =  0.0
# average error =  0.0003984625448388286
#
# ( 18 2 ); oldie error =  0.0
# average error =  0.0004431081961297453
#
# ( 18 3 ); oldie error =  0.0
# average error =  0.0004939950476633232
#
# ( 18 4 ); oldie error =  0.0
# average error =  0.0005523654123277017
#
# ( 18 5 ); oldie error =  0.0
# average error =  0.000613037473288923
#
# ( 18 6 ); oldie error =  0.0
# average error =  0.0006830940872773406
#
# ( 18 7 ); oldie error =  0.0
# average error =  0.0007583555504095601
#
# ( 18 8 ); oldie error =  0.0
# average error =  0.0008365999636252691
#
# ( 18 9 ); oldie error =  0.0
# average error =  0.0009187999231803896
#
# ( 18 10 ); oldie error =  0.0
# average error =  0.0009966396959601165
#
# ( 18 11 ); oldie error =  0.0
# average error =  0.0010703945728833624
#
# ( 18 12 ); oldie error =  0.0
# average error =  0.0011412559546414684
#
# ( 18 13 ); oldie error =  0.0
# average error =  0.0011946716150347833
#
# ( 18 14 ); oldie error =  0.0
# average error =  0.0012290924379191536
#
# ( 18 15 ); oldie error =  0.0
# average error =  0.0011405945832522338
#
# ( 18 16 ); oldie error =  0.0
# average error =  0.0009444652726841892
#
# ( 18 17 ); oldie error =  0.0
# average error =  0.0007552677437432362
#
# ( 18 18 ); oldie error =  0.0
# average error =  0.0008977562091431615
#
# ( 18 19 ); oldie error =  0.0
# average error =  0.0015651460999372962
#
# ( 18 20 ); oldie error =  0.0
# average error =  0.002181515019058996
#
# ( 18 21 ); oldie error =  0.0
# average error =  0.0026880697978706428
#
# ( 18 22 ); oldie error =  0.0
# average error =  0.0030046718329582323
#
# ( 18 23 ); oldie error =  0.0
# average error =  0.003190183106508488
#
# ( 18 24 ); oldie error =  0.0
# average error =  0.0032709302737194052
#
# ( 18 25 ); oldie error =  0.0
# average error =  0.003319681970152108
#
# ( 18 26 ); oldie error =  0.0
# average error =  0.0033454796961049768
#
# ( 18 27 ); oldie error =  0.0
# average error =  0.0033379333253267048
#
# ( 18 28 ); oldie error =  0.0
# average error =  0.0032865044577616727
#
# ( 18 29 ); oldie error =  0.0
# average error =  0.0031641221537484212
#
# ( 19 0 ); oldie error =  0.0
# average error =  0.00016639416797042895
#
# ( 19 1 ); oldie error =  0.0
# average error =  0.00017689629543373472
#
# ( 19 2 ); oldie error =  0.0
# average error =  0.00018939056081407742
#
# ( 19 3 ); oldie error =  0.0
# average error =  0.00020568171889092426
#
# ( 19 4 ); oldie error =  0.0
# average error =  0.0002245864342956943
#
# ( 19 5 ); oldie error =  0.0
# average error =  0.000247792327312466
#
# ( 19 6 ); oldie error =  0.0
# average error =  0.00027211017252401574
#
# ( 19 7 ); oldie error =  0.0
# average error =  0.0003003949082848278
#
# ( 19 8 ); oldie error =  0.0
# average error =  0.000331898726358912
#
# ( 19 9 ); oldie error =  0.0
# average error =  0.00036278650976290857
#
# ( 19 10 ); oldie error =  0.0
# average error =  0.000394082397694382
#
# ( 19 11 ); oldie error =  0.0
# average error =  0.00042502606400698147
#
# ( 19 12 ); oldie error =  0.0
# average error =  0.00045696505329946823
#
# ( 19 13 ); oldie error =  0.0
# average error =  0.0004833622257340448
#
# ( 19 14 ); oldie error =  0.0
# average error =  0.0005776210285260644
#
# ( 19 15 ); oldie error =  0.0
# average error =  0.0008278516186831937
#
# ( 19 16 ); oldie error =  0.0
# average error =  0.0011293660506583247
#
# ( 19 17 ); oldie error =  0.0
# average error =  0.0014323548047136645
#
# ( 19 18 ); oldie error =  0.0
# average error =  0.0017423167077557518
#
# ( 19 19 ); oldie error =  0.0
# average error =  0.0020252156489965296
#
# ( 19 20 ); oldie error =  0.0
# average error =  0.0022654931736410537
#
# ( 19 21 ); oldie error =  0.0
# average error =  0.0024105366991350337
#
# ( 19 22 ); oldie error =  0.0
# average error =  0.0025168851811953356
#
# ( 19 23 ); oldie error =  0.0
# average error =  0.0025595691361975864
#
# ( 19 24 ); oldie error =  0.0
# average error =  0.0025979434157052347
#
# ( 19 25 ); oldie error =  0.0
# average error =  0.0026259747459073976
#
# ( 19 26 ); oldie error =  0.0
# average error =  0.002648881525788939
#
# ( 19 27 ); oldie error =  0.0
# average error =  0.002662817162071819
#
# ( 19 28 ); oldie error =  0.0
# average error =  0.0026471386306823105
#
# ( 19 29 ); oldie error =  0.0
# average error =  0.0025855631617183244
#
# ( 20 0 ); oldie error =  0.0
# average error =  0.0004969528812023038
#
# ( 20 1 ); oldie error =  0.0
# average error =  0.0005398574471487186
#
# ( 20 2 ); oldie error =  0.0
# average error =  0.0005866074452340796
# ( 20 3 ); oldie error =  0.0
# average error =  0.0006367050261025213
#
# ( 20 4 ); oldie error =  0.0
# average error =  0.0006879794760448139
#
# ( 20 5 ); oldie error =  0.0
# average error =  0.0007522165586875787
#
# ( 20 6 ); oldie error =  0.0
# average error =  0.0008174529680816296
#
# ( 20 7 ); oldie error =  0.0
# average error =  0.0008879780839052625
#
# ( 20 8 ); oldie error =  0.0
# average error =  0.0009689144148960395
#
# ( 20 9 ); oldie error =  0.0
# average error =  0.001061193879431929
#
# ( 20 10 ); oldie error =  0.0
# average error =  0.001169706504735858
#
# ( 20 11 ); oldie error =  0.0
# average error =  0.001290336326878212
#
# ( 20 12 ); oldie error =  0.0
# average error =  0.0014427565518303454
#
# ( 20 13 ); oldie error =  0.0
# average error =  0.0016261724486984455
#
# ( 20 14 ); oldie error =  0.0
# average error =  0.0018513824156768993
#
# ( 20 15 ); oldie error =  0.0
# average error =  0.001965827965723167
#
# ( 20 16 ); oldie error =  0.0
# average error =  0.001965420558309999
#
# ( 20 17 ); oldie error =  0.0
# average error =  0.0019622720865584034
#
# ( 20 18 ); oldie error =  0.0
# average error =  0.0019723539301186
#
# ( 20 19 ); oldie error =  0.0
# average error =  0.001983956379378656
#
# ( 20 20 ); oldie error =  0.0
# average error =  0.0020046337220662354
#
# ( 20 21 ); oldie error =  0.0
# average error =  0.0020047779361101977
#
# ( 20 22 ); oldie error =  0.0
# average error =  0.0019996612299627422
#
# ( 20 23 ); oldie error =  0.0
# average error =  0.0020119293091009887
#
# ( 20 24 ); oldie error =  0.0
# average error =  0.0020298144395761546
#
# ( 20 25 ); oldie error =  0.0
# average error =  0.0020571122497057568
#
# ( 20 26 ); oldie error =  0.0
# average error =  0.0020854825789839294
#
# ( 20 27 ); oldie error =  0.0
# average error =  0.0021066810208941107
#
# ( 20 28 ); oldie error =  0.0
# average error =  0.0021115990526350712
#
# ( 20 29 ); oldie error =  0.0
# average error =  0.0020875912229851297
#
# ( 21 0 ); oldie error =  0.0
# average error =  0.0007454030485712904
#
# ( 21 1 ); oldie error =  0.0
# average error =  0.0008055154356078936
#
# ( 21 2 ); oldie error =  0.0
# average error =  0.0008706598353755853
#
# ( 21 3 ); oldie error =  0.0
# average error =  0.0009335656527184508
#
# ( 21 4 ); oldie error =  0.0
# average error =  0.0010011004219377842
#
# ( 21 5 ); oldie error =  0.0
# average error =  0.0010678705396340179
#
# ( 21 6 ); oldie error =  0.0
# average error =  0.0011408227221027108
#
# ( 21 7 ); oldie error =  0.0
# average error =  0.0012143804357914213
#
# ( 21 8 ); oldie error =  0.0
# average error =  0.0012932413401497663
#
# ( 21 9 ); oldie error =  0.0
# average error =  0.0013798575544264821
#
# ( 21 10 ); oldie error =  0.0
# average error =  0.0014713470620905539
#
# ( 21 11 ); oldie error =  0.0
# average error =  0.0015645775146564407
#
# ( 21 12 ); oldie error =  0.0
# average error =  0.0016811203704239978
#
# ( 21 13 ); oldie error =  0.0
# average error =  0.0018055565956112758
#
# ( 21 14 ); oldie error =  0.0
# average error =  0.001955954862791965
#
# ( 21 15 ); oldie error =  0.0
# average error =  0.0019647822964160132
#
# ( 21 16 ); oldie error =  0.0
# average error =  0.0018451583933504709
#
# ( 21 17 ); oldie error =  0.0
# average error =  0.0017396472852152574
#
# ( 21 18 ); oldie error =  0.0
# average error =  0.001671424733168615
#
# ( 21 19 ); oldie error =  0.0
# average error =  0.0016135424586694385
#
# ( 21 20 ); oldie error =  0.0
# average error =  0.0015833065373222067
#
# ( 21 21 ); oldie error =  0.0
# average error =  0.0015604796257009013
#
# ( 21 22 ); oldie error =  0.0
# average error =  0.0015488908244706055
#
# ( 21 23 ); oldie error =  0.0
# average error =  0.0015595732265713147
#
# ( 21 24 ); oldie error =  0.0
# average error =  0.0015762999185416206
#
# ( 21 25 ); oldie error =  0.0
# average error =  0.0015971171644099612
#
# ( 21 26 ); oldie error =  0.0
# average error =  0.0016266483138976295
#
# ( 21 27 ); oldie error =  0.0
# average error =  0.001653287100118148
#
# ( 21 28 ); oldie error =  0.0
# average error =  0.0016707927507516687
#
# ( 21 29 ); oldie error =  0.0
# average error =  0.0016676003392668544
#
# ( 22 0 ); oldie error =  0.0
# average error =  0.0006436232131032066
#
# ( 22 1 ); oldie error =  0.0
# average error =  0.0006941464010996037
#
# ( 22 2 ); oldie error =  0.0
# average error =  0.0007455317444412554
#
# ( 22 3 ); oldie error =  0.0
# average error =  0.0007975537247483425
#
# ( 22 4 ); oldie error =  0.0
# average error =  0.0008512915669742164
#
# ( 22 5 ); oldie error =  0.0
# average error =  0.0009061426340931956
#
# ( 22 6 ); oldie error =  0.0
# average error =  0.0009611317313262834
#
# ( 22 7 ); oldie error =  0.0
# average error =  0.0010168689864317065
#
# ( 22 8 ); oldie error =  0.0
# average error =  0.0010767945583058393
#
# ( 22 9 ); oldie error =  0.0
# average error =  0.0011399754518377429
#
# ( 22 10 ); oldie error =  0.0
# average error =  0.0012048389579395722
#
# ( 22 11 ); oldie error =  0.0
# average error =  0.0012793575616086596
#
# ( 22 12 ); oldie error =  0.0
# average error =  0.0013548171074699727
#
# ( 22 13 ); oldie error =  0.0
# average error =  0.0014428977177052388
#
# ( 22 14 ); oldie error =  0.0
# average error =  0.001546556628287976
#
# ( 22 15 ); oldie error =  0.0
# average error =  0.0015411660414201317
#
# ( 22 16 ); oldie error =  0.0
# average error =  0.0014285623587872534
#
# ( 22 17 ); oldie error =  0.0
# average error =  0.0013407400573953081
#
# ( 22 18 ); oldie error =  0.0
# average error =  0.0012769408360930124
#
# ( 22 19 ); oldie error =  0.0
# average error =  0.0012278515156499894
#
# ( 22 20 ); oldie error =  0.0
# average error =  0.0011963616812699774
#
# ( 22 21 ); oldie error =  0.0
# average error =  0.0011815230110453455
#
# ( 22 22 ); oldie error =  0.0
# average error =  0.001181227450960836
#
# ( 22 23 ); oldie error =  0.0
# average error =  0.0011905901864327185
#
# ( 22 24 ); oldie error =  0.0
# average error =  0.0012101713785191268
#
# ( 22 25 ); oldie error =  0.0
# average error =  0.0012343867661701743
#
# ( 22 26 ); oldie error =  0.0
# average error =  0.0012613904646854581
#
# ( 22 27 ); oldie error =  0.0
# average error =  0.001289114918883436
#
# ( 22 28 ); oldie error =  0.0
# average error =  0.0013103045572317859
#
# ( 22 29 ); oldie error =  0.0
# average error =  0.0013194978844885015
#
# ( 23 0 ); oldie error =  0.0
# average error =  0.00047529945676573357
#
# ( 23 1 ); oldie error =  0.0
# average error =  0.0005152829704506314
#
# ( 23 2 ); oldie error =  0.0
# average error =  0.0005554534359543007
#
# ( 23 3 ); oldie error =  0.0
# average error =  0.0005966678715904807
#
# ( 23 4 ); oldie error =  0.0
# average error =  0.0006367564275155315
#
# ( 23 5 ); oldie error =  0.0
# average error =  0.0006796660447734075
#
# ( 23 6 ); oldie error =  0.0
# average error =  0.0007227549281941792
#
# ( 23 7 ); oldie error =  0.0
# average error =  0.0007664807898269798
#
# ( 23 8 ); oldie error =  0.0
# average error =  0.0008124270097225726
#
# ( 23 9 ); oldie error =  0.0
# average error =  0.0008589533316142275
#
# ( 23 10 ); oldie error =  0.0
# average error =  0.0009074438424488021
#
# ( 23 11 ); oldie error =  0.0
# average error =  0.0009636340571612027
#
# ( 23 12 ); oldie error =  0.0
# average error =  0.0010220114819335417
#
# ( 23 13 ); oldie error =  0.0
# average error =  0.0010862197140717917
#
# ( 23 14 ); oldie error =  0.0
# average error =  0.0011608804075096517
#
# ( 23 15 ); oldie error =  0.0
# average error =  0.0011551398507568921
#
# ( 23 16 ); oldie error =  0.0
# average error =  0.0010715250780453094
#
# ( 23 17 ); oldie error =  0.0
# average error =  0.0010032036319323281
#
# ( 23 18 ); oldie error =  0.0
# average error =  0.0009530506426170163
#
# ( 23 19 ); oldie error =  0.0
# average error =  0.0009175536834292888
#
# ( 23 20 ); oldie error =  0.0
# average error =  0.0008959946427265328
#
# ( 23 21 ); oldie error =  0.0
# average error =  0.0008893485623213272
#
# ( 23 22 ); oldie error =  0.0
# average error =  0.0008918824592423967
#
# ( 23 23 ); oldie error =  0.0
# average error =  0.0009023687534168612
#
# ( 23 24 ); oldie error =  0.0
# average error =  0.0009204260793911136
#
# ( 23 25 ); oldie error =  0.0
# average error =  0.0009437714348865915
#
# ( 23 26 ); oldie error =  0.0
# average error =  0.0009703312980513374
#
# ( 23 27 ); oldie error =  0.0
# average error =  0.0009968565573354586
#
# ( 23 28 ); oldie error =  0.0
# average error =  0.0010196014332004304
#
# ( 23 29 ); oldie error =  0.0
# average error =  0.0010342726640734465
#
# ( 24 0 ); oldie error =  0.0
# average error =  0.0003330747321753923
# ( 24 1 ); oldie error =  0.0
# average error =  0.000364220294273795
#
# ( 24 2 ); oldie error =  0.0
# average error =  0.0003964221064716508
#
# ( 24 3 ); oldie error =  0.0
# average error =  0.00042918878143853714
#
# ( 24 4 ); oldie error =  0.0
# average error =  0.00046225691100797145
#
# ( 24 5 ); oldie error =  0.0
# average error =  0.0004955443963343718
#
# ( 24 6 ); oldie error =  0.0
# average error =  0.0005297499941436069
#
# ( 24 7 ); oldie error =  0.0
# average error =  0.0005656360709242975
#
# ( 24 8 ); oldie error =  0.0
# average error =  0.0006006657080320566
#
# ( 24 9 ); oldie error =  0.0
# average error =  0.0006395979266943548
#
# ( 24 10 ); oldie error =  0.0
# average error =  0.0006782570177117649
#
# ( 24 11 ); oldie error =  0.0
# average error =  0.0007192140748688066
#
# ( 24 12 ); oldie error =  0.0
# average error =  0.0007664981690313317
#
# ( 24 13 ); oldie error =  0.0
# average error =  0.0008169439933510852
#
# ( 24 14 ); oldie error =  0.0
# average error =  0.0008727601596493235
#
# ( 24 15 ); oldie error =  0.0
# average error =  0.0008675094903293313
#
# ( 24 16 ); oldie error =  0.0
# average error =  0.0008035062242979903
#
# ( 24 17 ); oldie error =  0.0
# average error =  0.0007518980629847982
#
# ( 24 18 ); oldie error =  0.0
# average error =  0.000713031669834954
#
# ( 24 19 ); oldie error =  0.0
# average error =  0.0006858558506675248
#
# ( 24 20 ); oldie error =  0.0
# average error =  0.000670023146847749
#
# ( 24 21 ); oldie error =  0.0
# average error =  0.000663457620944653
#
# ( 24 22 ); oldie error =  0.0
# average error =  0.0006679527125093705
#
# ( 24 23 ); oldie error =  0.0
# average error =  0.0006791243415071632
#
# ( 24 24 ); oldie error =  0.0
# average error =  0.0006961817736487768
#
# ( 24 25 ); oldie error =  0.0
# average error =  0.000717534088530127
#
# ( 24 26 ); oldie error =  0.0
# average error =  0.0007408320888989232
#
# ( 24 27 ); oldie error =  0.0
# average error =  0.00076518224298495
#
# ( 24 28 ); oldie error =  0.0
# average error =  0.0007867817262633778
#
# ( 24 29 ); oldie error =  0.0
# average error =  0.000803514452355331
#
# ( 25 0 ); oldie error =  0.0
# average error =  0.00022765712459660143
#
# ( 25 1 ); oldie error =  0.0
# average error =  0.0002523288317348961
#
# ( 25 2 ); oldie error =  0.0
# average error =  0.00027744189398130344
#
# ( 25 3 ); oldie error =  0.0
# average error =  0.00030395374433259456
#
# ( 25 4 ); oldie error =  0.0
# average error =  0.00033082616353736225
#
# ( 25 5 ); oldie error =  0.0
# average error =  0.00035827166660540397
#
# ( 25 6 ); oldie error =  0.0
# average error =  0.0003857313219259278
#
# ( 25 7 ); oldie error =  0.0
# average error =  0.00041433082854996217
#
# ( 25 8 ); oldie error =  0.0
# average error =  0.00044500137478938734
#
# ( 25 9 ); oldie error =  0.0
# average error =  0.00047401897456688226
#
# ( 25 10 ); oldie error =  0.0
# average error =  0.0005073577145493235
#
# ( 25 11 ); oldie error =  0.0
# average error =  0.0005397162429553156
#
# ( 25 12 ); oldie error =  0.0
# average error =  0.0005758645811009099
#
# ( 25 13 ); oldie error =  0.0
# average error =  0.0006164212064667156
#
# ( 25 14 ); oldie error =  0.0
# average error =  0.0006604570354372127
#
# ( 25 15 ); oldie error =  0.0
# average error =  0.000655976003880921
#
# ( 25 16 ); oldie error =  0.0
# average error =  0.0006069206182847002
#
# ( 25 17 ); oldie error =  0.0
# average error =  0.0005668063091443326
#
# ( 25 18 ); oldie error =  0.0
# average error =  0.0005358139644482652
#
# ( 25 19 ); oldie error =  0.0
# average error =  0.0005133435652043872
#
# ( 25 20 ); oldie error =  0.0
# average error =  0.0004999782237025623
#
# ( 25 21 ); oldie error =  0.0
# average error =  0.0004944285560432268
#
# ( 25 22 ); oldie error =  0.0
# average error =  0.0004971752648528791
#
# ( 25 23 ); oldie error =  0.0
# average error =  0.0005062547291674209
#
# ( 25 24 ); oldie error =  0.0
# average error =  0.0005211951203289438
#
# ( 25 25 ); oldie error =  0.0
# average error =  0.0005390762018194853
#
# ( 25 26 ); oldie error =  0.0
# average error =  0.0005598068651090905
#
# ( 25 27 ); oldie error =  0.0
# average error =  0.0005810830701586853
#
# ( 25 28 ); oldie error =  0.0
# average error =  0.0006009727233807803
#
# ( 25 29 ); oldie error =  0.0
# average error =  0.0006176159990734928
#
# ( 26 0 ); oldie error =  0.0
# average error =  0.00015564405870707835
#
# ( 26 1 ); oldie error =  0.0
# average error =  0.00017398510050376027
#
# ( 26 2 ); oldie error =  0.0
# average error =  0.00019374112378227934
#
# ( 26 3 ); oldie error =  0.0
# average error =  0.0002137837314730439
#
# ( 26 4 ); oldie error =  0.0
# average error =  0.00023528210498107124
#
# ( 26 5 ); oldie error =  0.0
# average error =  0.0002575544074226076
#
# ( 26 6 ); oldie error =  0.0
# average error =  0.0002803552475929788
#
# ( 26 7 ); oldie error =  0.0
# average error =  0.0003031763337007702
#
# ( 26 8 ); oldie error =  0.0
# average error =  0.00032718867940072666
#
# ( 26 9 ); oldie error =  0.0
# average error =  0.00035318752841192704
#
# ( 26 10 ); oldie error =  0.0
# average error =  0.0003778860122624617
#
# ( 26 11 ); oldie error =  0.0
# average error =  0.00040642416400298574
#
# ( 26 12 ); oldie error =  0.0
# average error =  0.0004341617350993323
#
# ( 26 13 ); oldie error =  0.0
# average error =  0.000465599602823593
#
# ( 26 14 ); oldie error =  0.0
# average error =  0.0005010548172694839
#
# ( 26 15 ); oldie error =  0.0
# average error =  0.0004987045223630371
#
# ( 26 16 ); oldie error =  0.0
# average error =  0.00046089712385954116
#
# ( 26 17 ); oldie error =  0.0
# average error =  0.00042924127756014985
#
# ( 26 18 ); oldie error =  0.0
# average error =  0.0004040847857865078
#
# ( 26 19 ); oldie error =  0.0
# average error =  0.0003854440745059927
#
# ( 26 20 ); oldie error =  0.0
# average error =  0.0003730230036490496
#
# ( 26 21 ); oldie error =  0.0
# average error =  0.00036748427417496854
#
# ( 26 22 ); oldie error =  0.0
# average error =  0.0003680683107135618
#
# ( 26 23 ); oldie error =  0.0
# average error =  0.0003740393645071527
#
# ( 26 24 ); oldie error =  0.0
# average error =  0.0003853507995714589
#
# ( 26 25 ); oldie error =  0.0
# average error =  0.0004000178016272282
#
# ( 26 26 ); oldie error =  0.0
# average error =  0.00041746867142405925
#
# ( 26 27 ); oldie error =  0.0
# average error =  0.00043584946407868
#
# ( 26 28 ); oldie error =  0.0
# average error =  0.0004533997558517176
#
# ( 26 29 ); oldie error =  0.0
# average error =  0.0004687826006001975
#
# ( 27 0 ); oldie error =  0.0
# average error =  0.00011449652172361464
#
# ( 27 1 ); oldie error =  0.0
# average error =  0.0002534243956273592
#
# ( 27 2 ); oldie error =  0.0
# average error =  0.0002797578841515068
#
# ( 27 3 ); oldie error =  0.0
# average error =  0.0003097005037800404
#
# ( 27 4 ); oldie error =  0.0
# average error =  0.0003417623965182419
#
# ( 27 5 ); oldie error =  0.0
# average error =  0.0003736612544135192
#
# ( 27 6 ); oldie error =  0.0
# average error =  0.0004098468596004486
#
# ( 27 7 ); oldie error =  0.0
# average error =  0.000446125396741135
#
# ( 27 8 ); oldie error =  0.0
# average error =  0.0004855862161958401
#
# ( 27 9 ); oldie error =  0.0
# average error =  0.0005230089110792683
#
# ( 27 10 ); oldie error =  0.0
# average error =  0.0005668784894868215
#
# ( 27 11 ); oldie error =  0.0
# average error =  0.0006116174171379353
#
# ( 27 12 ); oldie error =  0.0
# average error =  0.0006564403307882034
#
# ( 27 13 ); oldie error =  0.0
# average error =  0.000703995379317781
#
# ( 27 14 ); oldie error =  0.0
# average error =  0.0007581691967298038
#
# ( 27 15 ); oldie error =  0.0
# average error =  0.0007560075579468446
#
# ( 27 16 ); oldie error =  0.0
# average error =  0.0006983030474133079
#
# ( 27 17 ); oldie error =  0.0
# average error =  0.0006490186910043269
#
# ( 27 18 ); oldie error =  0.0
# average error =  0.0006084959810333024
#
# ( 27 19 ); oldie error =  0.0
# average error =  0.000576982711101251
#
# ( 27 20 ); oldie error =  0.0
# average error =  0.0005550340940002904
#
# ( 27 21 ); oldie error =  0.0
# average error =  0.0005427354822876503
#
# ( 27 22 ); oldie error =  0.0
# average error =  0.0005399828157436543
#
# ( 27 23 ); oldie error =  0.0
# average error =  0.00054653389543704
#
# ( 27 24 ); oldie error =  0.0
# average error =  0.0005616264909959571
#
# ( 27 25 ); oldie error =  0.0
# average error =  0.0005838126497370035
#
# ( 27 26 ); oldie error =  0.0
# average error =  0.0006111440944897491
#
# ( 27 27 ); oldie error =  0.0
# average error =  0.0006411842407028106
#
# ( 27 28 ); oldie error =  0.0
# average error =  0.0006713972005628131
# ( 27 29 ); oldie error =  0.0
# average error =  0.0006989062313258345
#
# ( 28 0 ); oldie error =  0.0
# average error =  0.00020996222945449792
#
# ( 28 1 ); oldie error =  0.0
# average error =  0.00022072015292912912
#
# ( 28 2 ); oldie error =  0.0
# average error =  0.00023304939247842979
#
# ( 28 3 ); oldie error =  0.0
# average error =  0.00024893977113087145
#
# ( 28 4 ); oldie error =  0.0
# average error =  0.00026869994805352475
#
# ( 28 5 ); oldie error =  0.0
# average error =  0.0002911410198594461
#
# ( 28 6 ); oldie error =  0.0
# average error =  0.0003141601932343983
#
# ( 28 7 ); oldie error =  0.0
# average error =  0.0003406603231992965
#
# ( 28 8 ); oldie error =  0.0
# average error =  0.00036860351046591407
#
# ( 28 9 ); oldie error =  0.0
# average error =  0.0003989372438387584
#
# ( 28 10 ); oldie error =  0.0
# average error =  0.00042856142136035746
#
# ( 28 11 ); oldie error =  0.0
# average error =  0.00046377965697493446
#
# ( 28 12 ); oldie error =  0.0
# average error =  0.0004998262917272287
#
# ( 28 13 ); oldie error =  0.0
# average error =  0.0005365741757468613
#
# ( 28 14 ); oldie error =  0.0
# average error =  0.000575745286029364
#
# ( 28 15 ); oldie error =  0.0
# average error =  0.0005729920060774672
#
# ( 28 16 ); oldie error =  0.0
# average error =  0.0005282268365335496
#
# ( 28 17 ); oldie error =  0.0
# average error =  0.0004892711168231763
#
# ( 28 18 ); oldie error =  0.0
# average error =  0.00045634761292785215
#
# ( 28 19 ); oldie error =  0.0
# average error =  0.00042976899794267264
#
# ( 28 20 ); oldie error =  0.0
# average error =  0.0004098277336750927
#
# ( 28 21 ); oldie error =  0.0
# average error =  0.0003970038646876617
#
# ( 28 22 ); oldie error =  0.0
# average error =  0.00039134286346822274
#
# ( 28 23 ); oldie error =  0.0
# average error =  0.0003930290631808608
#
# ( 28 24 ); oldie error =  0.0
# average error =  0.0004017936745850952
#
# ( 28 25 ); oldie error =  0.0
# average error =  0.0004169152790384099
#
# ( 28 26 ); oldie error =  0.0
# average error =  0.00043721202694338375
#
# ( 28 27 ); oldie error =  0.0
# average error =  0.0004609100152112889
#
# ( 28 28 ); oldie error =  0.0
# average error =  0.0004858402575290255
#
# ( 28 29 ); oldie error =  0.0
# average error =  0.0005095778991068226
#
# ( 29 0 ); oldie error =  0.0
# average error =  0.00021901016135640985
#
# ( 29 1 ); oldie error =  0.0
# average error =  0.00023034529705601967
#
# ( 29 2 ); oldie error =  0.0
# average error =  0.00024228814326475673
#
# ( 29 3 ); oldie error =  0.0
# average error =  0.00025216505082125746
#
# ( 29 4 ); oldie error =  0.0
# average error =  0.00026277309783645893
#
# ( 29 5 ); oldie error =  0.0
# average error =  0.00027182320471069146
#
# ( 29 6 ); oldie error =  0.0
# average error =  0.0002837457753110432
#
# ( 29 7 ); oldie error =  0.0
# average error =  0.0002968980619956564
#
# ( 29 8 ); oldie error =  0.0
# average error =  0.00031310289729071574
#
# ( 29 9 ); oldie error =  0.0
# average error =  0.00033151012622721263
#
# ( 29 10 ); oldie error =  0.0
# average error =  0.000352058893439868
#
# ( 29 11 ); oldie error =  0.0
# average error =  0.0003727623427910279
#
# ( 29 12 ); oldie error =  0.0
# average error =  0.00039835928697171667
#
# ( 29 13 ); oldie error =  0.0
# average error =  0.000424912000323115
#
# ( 29 14 ); oldie error =  0.0
# average error =  0.00045250543270397374
#
# ( 29 15 ); oldie error =  0.0
# average error =  0.00044614434069234894
#
# ( 29 16 ); oldie error =  0.0
# average error =  0.0004077084264968198
#
# ( 29 17 ); oldie error =  0.0
# average error =  0.00037405365699656675
#
# ( 29 18 ); oldie error =  0.0
# average error =  0.00034517786439171354
#
# ( 29 19 ); oldie error =  0.0
# average error =  0.00032113931967250664
#
# ( 29 20 ); oldie error =  0.0
# average error =  0.0003021751892192379
#
# ( 29 21 ); oldie error =  0.0
# average error =  0.00028842502978811406
#
# ( 29 22 ); oldie error =  0.0
# average error =  0.0002801370755106532
#
# ( 29 23 ); oldie error =  0.0
# average error =  0.0002775736754669344
#
# ( 29 24 ); oldie error =  0.0
# average error =  0.00028074703980534915
#
# ( 29 25 ); oldie error =  0.0
# average error =  0.0002893781058628903
#
# ( 29 26 ); oldie error =  0.0
# average error =  0.00030294369071337285
#
# ( 29 27 ); oldie error =  0.0
# average error =  0.00032024434066621173
#
# ( 29 28 ); oldie error =  0.0
# average error =  0.0003396778548021075
#
# ( 29 29 ); oldie error =  0.0
# average error =  0.00035932818577087103

# %% [markdown]
# ### Plot

# %%
fig = plt.figure(constrained_layout=True)
spec = fig.add_gridspec(ncols=3, nrows=1)

fig.add_subplot(spec[0, 0])
[X,Y] = np.meshgrid(T2/(g),pump/(g)) # define X,Y for contour plot
levels = np.logspace(-7,-4,15) # finetune gradation in contour plot
locator = ticker.LogLocator(base=10)
plt.contourf(X,Y, decay_rate/(omega_m), locator=ticker.LogLocator(), levels = levels, cmap = 'viridis_r') # plotting
cbar = plt.colorbar(ticks=[10**-7, 10**-6, 10**-5, 10**-4], aspect = 15, shrink = 0.5)
cbar.ax.tick_params() 
cbar.set_label('$\gamma_{eff}/\omega_m$')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$\gamma_2/g$')
plt.xticks()
plt.yticks()
plt.ylabel('$\Omega/g$')
plt.title('decay rate')
ax = plt.gca()
ax.set(adjustable='box', aspect='equal')

fig.add_subplot(spec[0, 1])
levels = np.linspace(0.7,1,15) # finetune gradation in contour plot
plt.contourf(X,Y, beta_array, levels = levels, cmap = 'viridis_r') # plotting
cbar = plt.colorbar(aspect = 15, shrink = 0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$\gamma_2/g$')
plt.xticks()
plt.yticks()
# plt.ylabel('$\Omega/g$')
plt.title('beta')
ax = plt.gca()
ax.set(adjustable='box', aspect='equal')


fig.add_subplot(spec[0, 2])
levels = np.logspace(-7,-1,15) # finetune gradation in contour plot
plt.contourf(X,Y, decay_rate*nth/(omega_m*phonon_ss), locator=ticker.LogLocator(), levels = levels, cmap = 'viridis_r') # plotting
cbar = plt.colorbar(aspect = 15, shrink = 0.5, ticks = [10**-7, 10**-5, 10**-3, 10**-1, 10**1])
cbar.ax.tick_params()
# cbar.ax.set_yticklabels([0.001, 0.1, 10, 1000])
cbar.set_label('$(\gamma_{eff}/\omega_m)/\mathcal{F}$')
plt.xscale('log')
plt.yscale('log')
plt.xticks()
plt.yticks()
# plt.ylabel('$\Omega/g$')
plt.xlabel('$\gamma_2/g$')
plt.title('ratio')
ax = plt.gca()
ax.set(adjustable='box', aspect='equal')
plt.rcParams.update({'font.size': 25})


fig = plt.gcf()
fig.set_size_inches((25, 9))

# plt.savefig('decay_polariton.png')

# %% [markdown]
# ### Manuscript Plot

# %%
'''
Import data
'''

polariton_phonon_decay_thermal = loadmat('./data files/polariton_phonon_decay_thermal_N_40.mat')
phonon_number_array = polariton_phonon_decay_thermal['phonon_number_array']
best_fit_array = polariton_phonon_decay_thermal['best_fit_array'][0]
t_final_array = polariton_phonon_decay_thermal['t_final_array']
phonon_ss = polariton_phonon_decay_thermal['phonon_ss']
decay_rate = polariton_phonon_decay_thermal['decay_rate']

pump = polariton_phonon_decay_thermal['pump'][0]
T2 = polariton_phonon_decay_thermal['T2'][0]
g = int(polariton_phonon_decay_thermal['g'])
omega_m = polariton_phonon_decay_thermal['omega_m'][0]
nth = polariton_phonon_decay_thermal['nth'][0]

# %%
'''
Prepare arrays to plot data. Import phonon number arrays, best fit arrays from stored data. Each array is called
through the index tuple (pump, T2): (i,j)
'''

# Phonon_1
i, j = 0, 15
phonon_1 = phonon_number_array[i,j]
phonon_best_fit_1 = best_fit_array[i*30+j][0]
time_1 = np.linspace(0, t_final_array[i,j], 5000)

# Phonon_2
i, j = 19, 15
phonon_2 = phonon_number_array[i,j]
phonon_best_fit_2 = best_fit_array[i*30+j][0]
time_2 = np.linspace(0, t_final_array[i,j], 5000)

# Phonon_3
i, j = 29, 15
phonon_3 = phonon_number_array[i,j]
phonon_best_fit_3 = best_fit_array[i*30+j][0]
time_3 = np.linspace(0, t_final_array[i,j], 5000)

# Phonon_4
i, j = 15, 0
phonon_4 = phonon_number_array[i,j]
phonon_best_fit_4 = best_fit_array[i*30+j][0]
time_4 = np.linspace(0, t_final_array[i,j], 5000)

# Phonon_5
i, j = 15, 19
phonon_5 = phonon_number_array[i,j]
phonon_best_fit_5 = best_fit_array[i*30+j][0]
time_5 = np.linspace(0, t_final_array[i,j], 5000)

# Phonon_6
i, j = 15, 29
phonon_6 = phonon_number_array[i,j]
phonon_best_fit_6 = best_fit_array[i*30+j][0]
time_6 = np.linspace(0, t_final_array[i,j], 5000)

# %%
'''
Plot!!
'''
ymax = phonon_1[0] + 1

fig = plt.figure(constrained_layout=True)
spec = fig.add_gridspec(ncols=4, nrows=6)

fig.add_subplot(spec[0:2, 0])
plt.semilogy(time_1, phonon_1, label = 'Phonon #',  linewidth = 2)
plt.semilogy(time_1[:len(phonon_best_fit_1)], phonon_best_fit_1, label = 'Best fit', linestyle = '--', color = '#ff7f0e', linewidth = 2)
plt.title('(a) $\gamma_2 = 1.08g, \Omega = 0.1g$', fontsize = 12)
plt.xticks([0, 3000, 6000, 9000], fontsize = 12)
plt.yticks([10, 0.1, 0.001], fontsize = 12)

fig.add_subplot(spec[2:4, 0])
plt.ylabel('Phonon Number', fontsize = 17)
plt.semilogy(time_2, phonon_2, label = 'Phonon #',  linewidth = 2)
plt.semilogy(time_2[:len(phonon_best_fit_2)], phonon_best_fit_2, label = 'Best fit', linestyle = '--', color = '#ff7f0e', linewidth = 2)
plt.title('(b) $\gamma_2 = 1.08g, \Omega = 2.04g$', fontsize = 12)
# legend = plt.legend(fontsize = 10, frameon = False)
plt.xticks([0, 250, 500, 750, 1000], fontsize = 12)
plt.yticks([10, 0.1, 0.001], fontsize = 12)

fig.add_subplot(spec[4:6, 0])
plt.semilogy(time_3, phonon_3, label = 'Phonon #',  linewidth = 2)
plt.semilogy(time_3[:len(phonon_best_fit_3)], phonon_best_fit_3, label = 'Best fit', linestyle = '--', color = '#ff7f0e', linewidth = 2)
plt.title('(c) $\gamma_2 = 1.08g, \Omega = 10g$', fontsize = 12)
plt.xlabel('Time ($\mu$s)', fontsize = 12)
# legend = plt.legend(fontsize = 10, frameon = False)
plt.xticks([0, 250, 500], fontsize = 12)
plt.yticks([10, 0.1, 0.001], fontsize = 12)

fig.add_subplot(spec[0:2, 1])
plt.semilogy(time_4, phonon_4, label = 'Phonon #',  linewidth = 2)
plt.semilogy(time_4[:len(phonon_best_fit_4)], phonon_best_fit_4, label = 'Best fit', linestyle = '--', color = '#ff7f0e', linewidth = 2)
plt.title('(d) $\gamma_2 = 0.1g, \Omega = 1.08g$', fontsize = 12)
# legend = plt.legend(fontsize = 10, frameon = False)
plt.xticks([0, 2500, 5000, 7500, 10000], fontsize = 12)
plt.yticks([])
plt.ylim(top = 10, bottom=0.001)

fig.add_subplot(spec[2:4, 1])
# plt.ylabel('Phonon Number', fontsize = 10)
plt.semilogy(time_5, phonon_5, label = 'Phonon #',  linewidth = 2)
plt.semilogy(time_5[:len(phonon_best_fit_5)], phonon_best_fit_5, label = 'Best fit', linestyle = '--', color = '#ff7f0e', linewidth = 2)
plt.title('(e) $\gamma_2 = 2.04g, \Omega = 1.08g$', fontsize = 12)
# legend = plt.legend(fontsize = 10, frameon = False)
plt.xticks([0, 250, 500, 750, 1000], fontsize = 12)
plt.yticks([])
# plt.ylim(top=ymax)
plt.ylim(top=10, bottom=0.001)

fig.add_subplot(spec[4:6, 1])
plt.semilogy(time_6, phonon_6, label = 'Phonon #',  linewidth = 2)
plt.semilogy(time_6[:len(phonon_best_fit_6)], phonon_best_fit_6, label = 'Best fit', linestyle = '--', color = '#ff7f0e', linewidth = 2)
plt.title('(f) $\gamma_2 = 10g, \Omega = 1.08g$', fontsize = 12)
plt.xlabel('Time ($\mu$s)', fontsize = 12)
legend = plt.legend(fontsize = 12, frameon = False)
plt.xticks([0, 250, 500, 750, 1000], fontsize = 12)
plt.yticks([])
plt.ylim(top=10, bottom=0.001)

fig.add_subplot(spec[0:3, 2:3])
[X,Y] = np.meshgrid(pump/g,T2/g) # define X,Y for contour plot
levels = np.logspace(-7,-4,15) # finetune gradation in contour plot
locator = ticker.LogLocator(base=10)
plt.contourf(X,Y, decay_rate/(omega_m), locator=ticker.LogLocator(), levels = levels, cmap = 'viridis_r') # plotting
cbar = plt.colorbar(ticks=locator, aspect = 18, shrink = 1)
cbar.ax.tick_params(labelsize=15) 
cbar.set_label('$\gamma_{eff}/\omega_m$', fontsize = 20)
plt.xscale('log')
plt.yscale('log')
plt.xticks([])
plt.yticks(fontsize = 15)
plt.ylabel('$\Omega/g$', fontsize = 17)
plt.title('(g)', fontsize = 12)
ax = plt.gca()
ax.set(adjustable='box', aspect='equal')

fig.add_subplot(spec[3:6, 2:3])
levels = np.logspace(-7,-1,15) # finetune gradation in contour plot
plt.contourf(X,Y, decay_rate*nth/(omega_m*phonon_ss), locator=ticker.LogLocator(), levels = levels, cmap = 'viridis_r') # plotting
cbar = plt.colorbar(aspect = 18, shrink = 1, ticks = [10**-7, 10**-5, 10**-3, 10**-1])
cbar.ax.tick_params(labelsize=15) 
cbar.set_label('$(\gamma_{eff}/\omega_m)/\mathcal{F}$', fontsize = 20)
plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('$\gamma_2/g$', fontsize = 17)
plt.ylabel('$\Omega/g$', fontsize = 17)
plt.title('(h)', fontsize = 15)
plt.xticks([10**-1, 1, 10], fontsize = 15)
ax = plt.gca()
ax.set(adjustable='box', aspect='equal')

fig = plt.gcf()
fig.set_size_inches((16, 6), forward=False)

plt.savefig('polariton_decay_combined.png', dpi = 500)
